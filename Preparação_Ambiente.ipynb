# %% [markdown]
# # INSTALAÇÃO DE BIBLIOTECAS E IMPORTAÇÕES

# %%
# 1. Base de Dados e Matemática
# !pip install numpy pandas scipy

# 2. Visualização de Dados
# !pip install matplotlib seaborn

# 3. Neurociência e Processamento de Sinais (EEG)
# !pip install mne mne-features

# 4. Machine Learning Tradicional
# !pip install scikit-learn xgboost joblib

# 5. Deep Learning (TensorFlow/Keras)
# !pip install tensorflow

# 6. IA Explicável (XAI)
# !pip install shap

# 7. Utilitários para Notebook e Performance
# !pip install ipykernel tqdm

# 8. Balanceamento de Dados Clínicos
# !pip install imbalanced-learn

# 9. Otimização Avançada de Modelos
# !pip install optuna keras-tuner

# 10. Decodificação Neural e Geometria Riemanniana (BCI)
# !pip install pyriemann

# 11. Inferência Probabilística e Modelagem Bayesiana
# !pip install pymc arviz

# 12. Versionamento de Dados para Ciência Aberta
# !pip install dvc
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 817.9 kB/s eta 0:00:00
# ...
#   Using cached tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/12.6 MB 4.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/12.6 MB 8.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/12.6 MB 22.8 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.6 MB 32.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.6 MB 40.6 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 37.2 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 54.4 MB/s eta 0:00:01
# ...

# %%
# 13. Plotagens Estatísticas e Interativas (Dashboard)
# !pip install plotly statsmodels bokeh

# 14. Processamento de Imagem (Análise de Espectrogramas e Visão)
# !pip install scikit-image opencv-python Pillow

# 15. Visualização Tridimensional (3D) e Manipulação de Malhas (Meshes)
# !pip install pyvista pyvistaqt ipywidgets

# 16. Interface 3D Moderna para o MNE (Crucial para Localização de Fonte)
# !pip install mne-qt-browser pyqt6

# 17. O Padrão Ouro de Gráficos + Backend de Janelas Interativas
# !pip install matplotlib PyQt5
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 3.6 MB/s eta 0:00:03
#     --------------------------------------- 0.2/9.9 MB 3.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/9.9 MB 2.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/9.9 MB 3.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/9.9 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/9.9 MB 4.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 5.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/9.9 MB 5.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.5/9.9 MB 6.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.0/9.9 MB 6.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.6/9.9 MB 7.5 MB/s eta 0:00:01
# ...

# %%
# 1. BASE DE DADOS, MATEMÁTICA E VETORES

import numpy as np
import pandas as pd
import scipy
from scipy import stats, signal, linalg

# 2. VISUALIZAÇÃO DE DADOS (ESTÁTICA)

import matplotlib.pyplot as plt
import seaborn as sns


# 3. NEUROCIÊNCIA E PROCESSAMENTO DE SINAIS (EEG)

import mne
import mne_features
from mne.decoding import CSP, Vectorizer # Ferramentas essenciais para BCI

# 4. MACHINE LEARNING TRADICIONAL

import sklearn
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import xgboost as xgb
import joblib

# 5. DEEP LEARNING (TENSORFLOW/KERAS)

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks

# 6. IA EXPLICÁVEL (XAI)

import shap

# 7. UTILITÁRIOS PARA NOTEBOOK E PERFORMANCE

import ipykernel
from tqdm.notebook import tqdm # Versão do tqdm otimizada para barras de progresso no Jupyter

# 8. BALANCEAMENTO DE DADOS CLÍNICOS

import imblearn
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline # Pipeline seguro para dados desbalanceados

# 9. OTIMIZAÇÃO AVANÇADA DE MODELOS (HIPERPARÂMETROS)

import optuna
import keras_tuner as kt

# 10. DECODIFICAÇÃO NEURAL E GEOMETRIA RIEMANNIANA

import pyriemann
from pyriemann.estimation import Covariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.classification import MDM

# 11. INFERÊNCIA PROBABILÍSTICA E MODELAGEM BAYESIANA

import pymc as pm
import arviz as az

# 12. VERSIONAMENTO DE DADOS (CIÊNCIA ABERTA)

import dvc.api

# 13. PLOTAGENS ESTATÍSTICAS E DASHBOARDS INTERATIVOS

import plotly.express as px
import plotly.graph_objects as go
import statsmodels.api as sm
import statsmodels.formula.api as smf
import bokeh.plotting as bkp

# 14. PROCESSAMENTO DE IMAGEM (ESPECTROGRAMAS E VISÃO)

import skimage
from skimage import io, filters, transform
import cv2
from PIL import Image

# 15. VISUALIZAÇÃO 3D E MANIPULAÇÃO DE MALHAS

import pyvista as pv
from pyvistaqt import BackgroundPlotter
import ipywidgets as widgets

# 16 & 17. BACKENDS DE INTERFACE GRÁFICA (QT)

import PyQt5
import PyQt6
# Para garantir que o MNE use a interface 3D moderna (mne-qt-browser):
mne.viz.set_browser_backend('qt')
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install gxx`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# c:\Users\tiago\AppData\Local\Programs\Python\Python311\Lib\site-packages\arviz\__init__.py:50: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(
# Using qt as 2D backend.

# %%
import pytensor

# 1. Avisa o sistema para parar de procurar o C++ e calar o aviso vermelho
pytensor.config.cxx = "" 

# 2. Muda a rota de compilação para o Numba, mantendo a performance altíssima
pytensor.config.mode = "NUMBA"
